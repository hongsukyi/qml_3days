# %% [markdown]
# 실습2: QML 파이프라인 (제공코드로 수정금지)

# %%
import pennylane as qml
from pennylane import numpy as np
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from IPython.display import clear_output

# ------------------------------
# 1. Data 준비
# ------------------------------
X_raw, y_raw = make_moons(n_samples=150, noise=0.15, random_state=42)
X = MinMaxScaler((0, np.pi)).fit_transform(X_raw)
Y = 2 * y_raw - 1

X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.3, random_state=42
)


# ------------------------------
# 3. 제공 함수
# ------------------------------
def init_weights():
    shape = qml.StronglyEntanglingLayers.shape(
        n_layers=2, n_wires=2
    )
    return np.array(
        0.1 * np.random.randn(*shape),
        requires_grad=True
    )

def loss(w, X, Y):
    preds = np.array([model(x, w) for x in X])
    return np.mean((preds - Y) ** 2)

def accuracy(w, X, Y):
    preds = np.sign(np.array([model(x, w) for x in X]))
    return np.mean(preds == Y)

# %%
##
## (아래에 코드를 작성하세)
